# %%
import h5py
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from matplotlib.widgets import Slider
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import binned_statistic_2d
from scipy.interpolate import make_splprep

# %%
gampix = np.load('analyzed_data/muon1k_0-1gev_gampix_estimators_test.npz')
edep = np.load('analyzed_data/muon1k_0-1gev_estimators_edep.npz')

print(data.keys())
print(edep.keys())

gampix_energies = gampix['energies']
gampix_naive = gampix['naive']
gampix_detailed = gampix['detailed']
gampix_evs = gampix['evs']

edep_energies = edep['energies']
edep_naive = edep['naive']
edep_naive = edep_naive[gampix_evs] / 10
edep_detailed = edep['detailed'] 
edep_detailed = edep_detailed[gampix_evs] / 100
# Out:
# KeysView(NpzFile 'analyzed_data/muon1k_0-1gev_gampix_estimators_test.npz' with keys: naive, detailed, charge, evs, energies)
# KeysView(NpzFile 'analyzed_data/muon1k_0-1gev_estimators_edep.npz' with keys: energies, naive, detailed, edeps, evs)

# %%
x = np.linspace(0, 450, 100)
plt.figure()
plt.plot(edep_naive, gampix_naive, 'o', color='lightgray')
plt.plot(x, x, color='black', linewidth=0.5)
plt.xlabel('naive length, truth (cm)')
plt.ylabel('naive length, gampix (cm)')
plt.title('naive length comparison')

plt.figure()
plt.plot(edep_detailed, gampix_detailed, 'o', color='lightgray')
plt.plot(x, x, color='black', linewidth = 0.5)
plt.xlabel('detailed length, truth (cm)')
plt.ylabel('detailed length, gampix (cm)')
plt.title('detailed length comparison')
# Out:
# Text(0.5, 1.0, 'detailed length comparison')
